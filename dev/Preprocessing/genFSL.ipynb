# %%
from PIL import Image
import skimage.io

import os
from pathlib import Path

from matplotlib import pyplot as plt
import numpy as np
import math 
import os
import shutil
import numpy as np
from datetime import datetime
import Augmentor
import cv2

# %%
purple = np.array([255, 27, 255, 255])
yellow = np.array([255, 255, 27, 255])
blue = np.array([27, 27, 255, 255])
red = np.array([255, 27, 27, 255])
lightblue = np.array([27, 255, 255, 255])
green = np.array([27, 255, 27, 255])
orange = np.array([255, 155, 27, 255])
white = np.array([255, 255, 255, 255])
black = np.array([0, 0, 0, 255])

rmFuncMap = {
    'bedroom': purple,
    'livingroom': yellow,
    'bathroom': blue,
    'kitchen': red,
    'storageroom': lightblue,
    'deckNporch': green,
    'corridor': orange,
    'background': white,
}

blWhMap = {
    'black': black,
    'white': white,
}

augmentedPath = Path('/home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/')
augmentedPath.mkdir(parents=True, exist_ok=True)
sourcePath = Path('/home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Source Images')
oriPath = Path('/home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Original')
pathA = augmentedPath / 'A'
pathA.mkdir(parents=True, exist_ok=True)
pathB = augmentedPath / 'B'
pathB.mkdir(parents=True, exist_ok=True)
newCombinedPath = augmentedPath / f"Combined_{datetime.now().strftime('%Y_%m_%d_%H_%M')}"
newCombinedPath.mkdir(parents=True, exist_ok=True)
# pathB_processed = augmentedPath / f"B_processed"
# pathB_processed.mkdir(parents=True, exist_ok=True)

test_dir = newCombinedPath / 'Test'
train_dir = newCombinedPath / 'Train'
test_dir.mkdir(parents=True, exist_ok=True)
train_dir.mkdir(parents=True, exist_ok=True)

# %%
def replaceCloestColor(img, rmFuncMap): 
    thresh = 30
    
    # Select room colors that are common in the image  
    vals, counts = np.unique(img.reshape(-1, 4), axis=0, return_counts=True)
    
    imgRmColor = set(map(tuple, vals[counts>thresh])) # form a set of values/counts > threshold
    rmColorMap = set(map(tuple, rmFuncMap.values())) # form a set of room func color map

    rmColor = np.array(list(imgRmColor.intersection(rmColorMap))) # Select the resonable colors in the room func map only
    
    # Determine color differences (Use additional dimension)
    # Compute the shortest Euclidean distance within the color map 
    color_diffs = np.sum((img[:,:,None,:]-rmColor)[...,:-1]**2,axis=-1)**0.5
    
    # Get the indices of the closest value
    idx = np.argmin(color_diffs,axis=-1)

    # Extract closest value to assemble array 
    img = rmColor[idx]
    
    return img 

def generateBlWhImg(img): 
    iswhite = (img == white).all(axis=2)
    img[~iswhite] = black
    return img

def unblur(img):
    sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
    sharpen = cv2.filter2D(img, -1, sharpen_kernel)
    return sharpen

# %%
p = Augmentor.Pipeline(oriPath / 'B')
p.ground_truth(sourcePath)

# Add operations to the pipeline:
p.rotate90(probability=0.25)
p.rotate270(probability=0.25)
p.flip_left_right(probability=0.25)
p.flip_top_bottom(probability=0.25)

IMAGE_COUNT = 300
p.sample(IMAGE_COUNT)

for file in (oriPath / 'B' / 'output').glob("*.png"):
    if 'original' in file.name:
        dst = pathA / file.name[-16:]
    elif '_groundtruth_' in file.name:
        dst = pathB / file.name[-16:]
        
    shutil.copyfile(file, dst)
shutil.rmtree(oriPath / 'B' / 'output')
# Out:
# Initialised with 104 image(s) found.
# Output directory set to /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Original/B/output.
# 104 ground truth image(s) found.
# Processing <PIL.Image.Image image mode=RGBA size=256x256 at 0x7F6330A83B70>: 100%|██████████| 300/300 [00:01<00:00, 231.47 Samples/s]

# %%
myfile = Path('/home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Source Images/0.png')
img = skimage.io.imread(myfile)
plt.imshow(img)

# %%
myfile = Path('/home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/B/00aaeaeb853b.png')
img = skimage.io.imread(myfile)

# img = generateBlWhImg(img.copy())
img = unblur(img.copy())
plt.imshow(img)
unique_pix_val = np.unique(img.reshape(-1, 4), axis=0)
print(unique_pix_val.shape)
# Out:
# (253, 4)

# %%
newCombinedPath.mkdir(parents=True, exist_ok=True)

# Combine Augmented Images into the pair format that Pix2Pix expects
for file in pathA.glob("*.png"):
  
  im1 = skimage.io.imread(file)
  # im2 = skimage.io.imread(oriPath / 'A' / file.name)
  im2 = skimage.io.imread(pathB / file.name)
  dst = np.hstack((replaceCloestColor(im1, rmFuncMap), unblur(im2)))
  skimage.io.imsave(newCombinedPath / file.name, dst)
# Out:
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/dd6498cc7938.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/4cffc60851c2.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/1853dcf071c5.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/405e563a9c84.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/b6c1b684fb5a.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/fc3112afcc2b.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/9dc91f1722fb.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/6ceccdfe713e.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/7fc6688670fa.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/2868eb99166f.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/d36b28f59aa7.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/d7b7d51aed52.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/2e965f0b722f.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/ba7504514fd9.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/bc30625b927d.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/0c86ade413ac.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/b42158168ff9.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/97958af2d314.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/65393786d0c3.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/7722695f2d20.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/b6075713f623.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/1eef939a8951.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/c124e383930f.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/e9db802edf8e.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/d7d5df28260a.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/397d4c3054ce.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/468a6d0d2b95.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/cdd67582fa17.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/ee7d2b46a8c3.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/0e5e61868672.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/71fb3f432619.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/22193067dfd5.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/3c8b0bb9f52a.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/1e2508bf5efe.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/eb1199ed0b38.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/fd7ec163217b.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/293b45005cf2.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/67039d9fb01b.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/64d0d0266057.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/5f1471e3d79e.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/e5ea0275a070.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/fd7275a364ed.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/e9a05125bec5.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/ecbff32f38bc.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/5875cf1c74f5.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/fb848beecb9d.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/79b691d043d0.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/7cad5cae6ea0.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/e09ec07169d4.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/b716407e6a50.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/527105350e89.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/0922b6b153b2.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/2c165abba026.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/0db29f870160.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/459a3228185c.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/41558dde066c.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/7c439ad76782.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/dc978764a2c4.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/692f84dc2b0b.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/8f1451d5a017.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/7137f4a8d1ed.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/8c3e71b55e25.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/675ecb4f83e8.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/88825b5db63c.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/b9dd23526f65.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/d35f59491e22.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/093c6127f23f.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/1d42fa0f4679.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/8ad6dc580dbf.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/3d0322f40ec6.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/e223e11f80b8.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/f58aa963a7e1.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/0403879ddfb2.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/5769c049457c.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/0db34a21c753.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/b65f203c0af0.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/25243def4a9e.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/bbb82ceccf8f.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/02b98e5ce4fb.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/ad13bad980d7.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/855ef43883dd.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/f3845a7340a0.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/9d04166b761a.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/0b5b2d6f23d4.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/266df71a2895.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/03cb6b84092b.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/542462a73a6e.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/2d93a214e343.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/bad50c51dde6.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/e63cf9abf842.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/ff2434170202.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/de279df7e0be.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/35bcb298a217.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/e679c29c15a5.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/88164ebb2d1f.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/f8d74f3c20b9.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/66af35aca965.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/fe9c959300c7.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/f2e0a61ddf5b.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/43a48c7fb75d.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/0f25fdfb444e.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/205e345230fd.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/4357148095dd.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/371907b07849.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/4e79d35d4e7a.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/c65be2b31eee.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/2d4296b8f895.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/c9f8b662aa15.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/445d02881b8b.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/9fe5d79ad7e9.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/39e91a1430f7.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/72bdb4056bcc.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/fbc2fd5192a2.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# ...
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/c86eeb497b29.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/fb1f1b52da68.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/c854041b246c.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/e992c163fe93.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/e0cc07f7f0e7.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/3461ed3add3b.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/fba25b23f5ce.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/2bc884588115.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/e5e74840a505.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/8cd3eb917d7e.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/82d57c7ee617.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/ccf778277eea.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/57694ac8b26f.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/03f13cd2e736.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/de93161240d6.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/ff679d442e87.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/71910894052b.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/17c483a1d660.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/0bd6be97a40a.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/f2d0a0ef8266.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/fdfe23213fd9.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/6e4ae838ed87.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/4aaa250e517a.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/a06126b46ef9.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/4b49a6cf97e0.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/ff8fb5fb1c5d.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/b89a656f242c.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/79bf5b9ebeef.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/c131294b99db.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/d006bcdfdaf0.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/3c5d78724885.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/7198cd7800a1.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/62f2aaa99571.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/da6797005aeb.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/1354ce73cf2c.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/155839efb331.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# /home/user1/anaconda3/envs/pix2pix/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: /home/user1/Documents/Ricky/pix2pix-floorplans-dataset/dataset/Augmented_floorplan/Combined_2023_03_09_15_17/7faf5ff92378.png is a low contrast image
#   # Remove the CWD from sys.path while we load stuff.
# Lossy conversion from int64 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.

# %%
ratio = 0.15

test_dir.mkdir(parents=True, exist_ok=True)
train_dir.mkdir(parents=True, exist_ok=True)

for file in newCombinedPath.glob("*.png"):
      if np.random.rand(1) < ratio:
          shutil.copyfile(file, test_dir / file.name)
      else:
          shutil.copyfile(file, train_dir / file.name)
